# %%
# !pip install pdfminer.six
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\muskan\anaconda3\lib\site-packages (from pdfminer.six) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\muskan\anaconda3\lib\site-packages (from pdfminer.six) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\muskan\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\muskan\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.6 MB 2.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/6.6 MB 1.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.0/6.6 MB 1.3 MB/s eta 0:00:05
#    --------- ------------------------------ 1.6/6.6 MB 1.5 MB/s eta 0:00:04
#    --------- ------------------------------ 1.6/6.6 MB 1.5 MB/s eta 0:00:04
#    ------------ --------------------------- 2.1/6.6 MB 1.4 MB/s eta 0:00:04
#    --------------- ------------------------ 2.6/6.6 MB 1.6 MB/s eta 0:00:03
#    --------------- ------------------------ 2.6/6.6 MB 1.6 MB/s eta 0:00:03
#    ------------------- -------------------- 3.1/6.6 MB 1.5 MB/s eta 0:00:03
#    -------------------- ------------------- 3.4/6.6 MB 1.5 MB/s eta 0:00:03
#    ------------------------- -------------- 4.2/6.6 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.7/6.6 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 5.2/6.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.8/6.6 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 6.3/6.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 1.9 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20260107
# Collecting spacy
#   Downloading spacy-3.8.14-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\muskan\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\muskan\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\muskan\anaconda3\lib\site-packages (from spacy) (2.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\muskan\anaconda3\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\muskan\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\muskan\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\muskan\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\muskan\anaconda3\lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muskan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\muskan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\muskan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\muskan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\muskan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\muskan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\muskan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.10.5)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama in c:\users\muskan\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\muskan\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\muskan\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.5.0)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\muskan\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in c:\users\muskan\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\muskan\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\muskan\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: wrapt in c:\users\muskan\anaconda3\lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\muskan\anaconda3\lib\site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\muskan\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.14-cp313-cp313-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 1.0 MB/s eta 0:00:14
#    -- ------------------------------------- 0.8/14.2 MB 1.1 MB/s eta 0:00:12
#    -- ------------------------------------- 1.0/14.2 MB 1.2 MB/s eta 0:00:11
#    --- ------------------------------------ 1.3/14.2 MB 1.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.6/14.2 MB 1.2 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.8/14.2 MB 1.2 MB/s eta 0:00:11
#    ------ --------------------------------- 2.4/14.2 MB 1.3 MB/s eta 0:00:10
#    ------- -------------------------------- 2.6/14.2 MB 1.4 MB/s eta 0:00:09
#    -------- ------------------------------- 3.1/14.2 MB 1.5 MB/s eta 0:00:08
#    --------- ------------------------------ 3.4/14.2 MB 1.5 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.2/14.2 MB 1.6 MB/s eta 0:00:07
#    ------------- -------------------------- 4.7/14.2 MB 1.7 MB/s eta 0:00:06
#    --------------- ------------------------ 5.5/14.2 MB 1.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.0/14.2 MB 1.9 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.3/14.2 MB 1.8 MB/s eta 0:00:05
#    ------------------ --------------------- 6.6/14.2 MB 1.8 MB/s eta 0:00:05
#    ------------------- -------------------- 7.1/14.2 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 7.6/14.2 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.9/14.2 MB 1.8 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.1/14.2 MB 1.9 MB/s eta 0:00:04
#    ------------------------ --------------- 8.7/14.2 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 8.9/14.2 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 9.7/14.2 MB 1.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.0/14.2 MB 1.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 10.5/14.2 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 11.0/14.2 MB 1.9 MB/s eta 0:00:02
#    ------------------------------- -------- 11.3/14.2 MB 1.9 MB/s eta 0:00:02
#    --------------------------------- ------ 12.1/14.2 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 12.8/14.2 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 13.1/14.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  13.9/14.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 2.0 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp313-cp313-win_amd64.whl (122 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp313-cp313-win_amd64.whl (650 kB)
#    ---------------------------------------- 0.0/650.8 kB ? eta -:--:--
#    -------------------------------- ------- 524.3/650.8 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 650.8/650.8 kB 2.8 MB/s eta 0:00:00
# Downloading thinc-8.3.13-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.7 MB/s eta 0:00:00
# Downloading blis-1.3.3-cp313-cp313-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.2 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/6.2 MB 2.3 MB/s eta 0:00:03
#    -------- ------------------------------- 1.3/6.2 MB 2.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.8/6.2 MB 2.4 MB/s eta 0:00:02
#    --------------- ------------------------ 2.4/6.2 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.4/6.2 MB 2.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.7/6.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.2 MB 2.7 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 2.7 MB/s eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, murmurhash, cymem, confection, cloudpathlib, catalogue, blis, srsly, preshed, weasel, thinc, spacy
#
#    -- -------------------------------------  1/14 [spacy-loggers]
#    ----- ----------------------------------  2/14 [spacy-legacy]
#    -------------- -------------------------  5/14 [confection]
#    ----------------- ----------------------  6/14 [cloudpathlib]
#    ---------------------- -----------------  8/14 [blis]
#    ---------------------- -----------------  8/14 [blis]
#    ------------------------- --------------  9/14 [srsly]
#    ------------------------- --------------  9/14 [srsly]
#    ------------------------- --------------  9/14 [srsly]
#    ------------------------- --------------  9/14 [srsly]
#    ------------------------- --------------  9/14 [srsly]
#    ------------------------- --------------  9/14 [srsly]
#    ------------------------------- -------- 11/14 [weasel]
#    ------------------------------- -------- 11/14 [weasel]
#    ---------------------------------- ----- 12/14 [thinc]
#    ---------------------------------- ----- 12/14 [thinc]
#    ---------------------------------- ----- 12/14 [thinc]
#    ---------------------------------- ----- 12/14 [thinc]
#    ---------------------------------- ----- 12/14 [thinc]
#    ---------------------------------- ----- 12/14 [thinc]
#    ---------------------------------- ----- 12/14 [thinc]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ---------------------------------------- 14/14 [spacy]
#
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-1.3.3 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.13 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 wasabi-1.1.3 weasel-1.0.0
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------ 0.8/12.8 MB 902.0 kB/s eta 0:00:14
#      -- ------------------------------------ 0.8/12.8 MB 902.0 kB/s eta 0:00:14
#      --- ----------------------------------- 1.0/12.8 MB 800.0 kB/s eta 0:00:15
#      --- ----------------------------------- 1.3/12.8 MB 950.5 kB/s eta 0:00:13
#      ---- ----------------------------------- 1.6/12.8 MB 1.0 MB/s eta 0:00:11
#      ------ --------------------------------- 2.1/12.8 MB 1.2 MB/s eta 0:00:10
#      -------- ------------------------------- 2.6/12.8 MB 1.3 MB/s eta 0:00:08
#      --------- ------------------------------ 2.9/12.8 MB 1.3 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.4/12.8 MB 1.4 MB/s eta 0:00:07
#      ------------ --------------------------- 3.9/12.8 MB 1.5 MB/s eta 0:00:06
#      ------------ --------------------------- 3.9/12.8 MB 1.5 MB/s eta 0:00:06
#      ------------- -------------------------- 4.5/12.8 MB 1.5 MB/s eta 0:00:06
#      --------------- ------------------------ 5.0/12.8 MB 1.5 MB/s eta 0:00:06
#      ----------------- ---------------------- 5.5/12.8 MB 1.6 MB/s eta 0:00:05
#      ------------------ --------------------- 6.0/12.8 MB 1.6 MB/s eta 0:00:05
#      ------------------- -------------------- 6.3/12.8 MB 1.7 MB/s eta 0:00:04
#      -------------------- ------------------- 6.6/12.8 MB 1.7 MB/s eta 0:00:04
#      ---------------------- ----------------- 7.3/12.8 MB 1.7 MB/s eta 0:00:04
#      ------------------------ --------------- 7.9/12.8 MB 1.8 MB/s eta 0:00:03
#      ------------------------- -------------- 8.1/12.8 MB 1.7 MB/s eta 0:00:03
#      --------------------------- ------------ 8.9/12.8 MB 1.8 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.4/12.8 MB 1.8 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.8 MB 1.9 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.9 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 2.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.8 MB 1.9 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 1.9 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 1.9 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from pdfminer.high_level import extract_text
import os

def extract_skills_from_pdf(pdf_path):
    return extract_text(pdf_path)

sample_text = extract_skills_from_pdf('resume.pdf')
print(sample_text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 def extract_skills_from_pdf(pdf_path):
#       5     return extract_text(pdf_path)
# ----> 7 sample_text = extract_skills_from_pdf('resume(4).pdf')
#       8 print(sample_text)
#
# Cell In[2], line 5, in extract_skills_from_pdf(pdf_path)
#       4 def extract_skills_from_pdf(pdf_path):
# ----> 5     return extract_text(pdf_path)
#
# File c:\Users\muskan\anaconda3\Lib\site-packages\pdfminer\high_level.py:172, in extract_text(pdf_file, password, page_numbers, maxpages, caching, codec, laparams)
#     169 if laparams is None:
#     170     laparams = LAParams()
# --> 172 with open_filename(pdf_file, "rb") as fp, StringIO() as output_string:
#     173     fp = cast(BinaryIO, fp)  # we opened in binary mode
#     174     rsrcmgr = PDFResourceManager(caching=caching)
#
# File c:\Users\muskan\anaconda3\Lib\site-packages\pdfminer\utils.py:46, in open_filename.__init__(self, filename, *args, **kwargs)
#      44     filename = str(filename)
#      45 if isinstance(filename, str):
# ---> 46     self.file_handler: AnyIO = open(filename, *args, **kwargs)  # noqa: SIM115
#      47     self.closing = True
#      48 elif isinstance(filename, io.IOBase):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resume(4).pdf'
